# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')
data
# Out:
#      tech_company      benefits workplace_resources mh_employer_discussion  \
# 0             Yes            No        I don't know                     No
# 1             Yes           Yes                  No                     No
# 2             Yes  I don't know                  No                    Yes
# 3             Yes           Yes        I don't know                    Yes
# 4             Yes           Yes                  No                     No
# ...           ...           ...                 ...                    ...
# 1237           No  I don't know                  No                     No
# 1238           No           Yes                 Yes                     No
# 1239           No           Yes                 Yes                    Yes
# 1240          Yes           Yes                 Yes                     No
# 1241          Yes            No                  No                     No
#
# ...

# %%
data.isnull().sum()
# Out:
# tech_company              0
# benefits                  0
# workplace_resources       0
# mh_employer_discussion    0
# mh_coworker_discussion    0
# medical_coverage          0
# mental_health             0
# mh_share                  0
# age                       0
# gender                    0
# country                   0
# dtype: int64

# %%
data.dtypes
# Out:
# tech_company              object
# benefits                  object
# workplace_resources       object
# mh_employer_discussion    object
# mh_coworker_discussion    object
# medical_coverage          object
# mental_health             object
# mh_share                   int64
# age                        int64
# gender                    object
# country                   object
# dtype: object

# %%
data.columns
# Out:
# Index(['tech_company', 'benefits', 'workplace_resources',
#        'mh_employer_discussion', 'mh_coworker_discussion', 'medical_coverage',
#        'mental_health', 'mh_share', 'age', 'gender', 'country'],
#       dtype='object')

# %%
data.shape
# Out:
# (1242, 11)

# %%
df = data.copy()

# %%
df.nunique()
# Out:
# tech_company               2
# benefits                   3
# workplace_resources        3
# mh_employer_discussion     2
# mh_coworker_discussion     2
# medical_coverage           2
# mental_health              4
# mh_share                  11
# age                       48
# gender                     3
# country                   30
# dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# United States of America    947
# United Kingdom               94
# Canada                       37
# Germany                      34
# Spain                        22
# France                       21
# Netherlands                  20
# Brazil                       12
# India                        11
# Portugal                      8
# Australia                     5
# Ireland                       5
# Mexico                        3
# Indonesia                     2
# Norway                        2
# Philippines                   2
# Estonia                       2
# Finland                       2
# Switzerland                   2
# Pakistan                      1
# Mauritius                     1
# Poland                        1
# Japan                         1
# Sweden                        1
# Greece                        1
# Mongolia                      1
# Macedonia                     1
# Austria                       1
# Kenya                         1
# ...

# %%
df['benefits'].value_counts()
# Out:
# benefits
# Yes             781
# I don't know    308
# No              153
# Name: count, dtype: int64

# %%
df['workplace_resources'].value_counts()
# Out:
# workplace_resources
# No              465
# Yes             431
# I don't know    346
# Name: count, dtype: int64

# %%
df['medical_coverage'].value_counts()
# Out:
# medical_coverage
# Yes    1147
# No       95
# Name: count, dtype: int64

# %%
df['mental_health'].value_counts()
df['mental_health'] = df['mental_health'].apply(lambda x: 1 if x == "Yes" or x == "Possibly" else 0)

# %%
df = df[df['gender'] != 'Other']
df
# Out:
#      tech_company      benefits workplace_resources mh_employer_discussion  \
# 0             Yes            No        I don't know                     No
# 1             Yes           Yes                  No                     No
# 2             Yes  I don't know                  No                    Yes
# 3             Yes           Yes        I don't know                    Yes
# 4             Yes           Yes                  No                     No
# ...           ...           ...                 ...                    ...
# 1237           No  I don't know                  No                     No
# 1238           No           Yes                 Yes                     No
# 1239           No           Yes                 Yes                    Yes
# 1240          Yes           Yes                 Yes                     No
# 1241          Yes            No                  No                     No
#
# ...

# %%
df.describe()
# Out:
#        mental_health     mh_share          age
# count    1188.000000  1188.000000  1188.000000
# mean        0.644781     6.560606    35.116162
# std         0.478781     2.695223     8.195791
# min         0.000000     0.000000    19.000000
# 25%         0.000000     5.000000    29.000000
# 50%         1.000000     7.000000    34.000000
# 75%         1.000000     9.000000    40.000000
# max         1.000000    10.000000    66.000000

# %%
y = df['mental_health']
X = df.drop(['mental_health'], axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in X.columns:
    plt.figure(figsize=(15, 10))
    sns.countplot(x=X[col], order=X[col].value_counts().index)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
for col in X.columns:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=X[col], hue=y, order=X[col].value_counts().index)
    plt.title(f'{col} vs Target')
    plt.xticks(rotation=45)
    plt.show()

# %%
import scipy.stats as stats
import numpy as np


def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2 = stats.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    return np.sqrt(phi2 / min(k - 1, r - 1))


corr_matrix = pd.DataFrame(index=X.columns, columns=X.columns)

for col1 in X.columns:
    for col2 in X.columns:
        corr_matrix.loc[col1, col2] = cramers_v(X[col1], X[col2])

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix.astype(float), annot=True, cmap="coolwarm")
plt.title("Cramér's V Correlation Heatmap")
plt.show()

# %%
y.value_counts()
# Out:
# mental_health
# 1    766
# 0    422
# Name: count, dtype: int64

# %%
df['workplace_resources'].value_counts()
# Out:
# workplace_resources
# No              442
# Yes             410
# I don't know    336
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
column_list_OneHotEnc = ['benefits', 'workplace_resources', 'country']
column_list_label = ['mh_employer_discussion', 'mh_coworker_discussion', 'medical_coverage', 'tech_company', 'gender']

# %%
from sklearn.preprocessing import LabelEncoder, TargetEncoder, OneHotEncoder

label_encoder = LabelEncoder()
for col in column_list_label:
    X_train[col] = label_encoder.fit_transform(X_train[col])
    X_test[col] = label_encoder.transform(X_test[col])

X_test
# Out:
#       tech_company      benefits workplace_resources  mh_employer_discussion  \
# 328              1           Yes        I don't know                       1
# 1208             1           Yes                  No                       0
# 948              0           Yes                 Yes                       0
# 89               0           Yes        I don't know                       0
# 979              0           Yes        I don't know                       0
# ...            ...           ...                 ...                     ...
# 341              1            No                 Yes                       0
# 53               0            No                  No                       0
# 1232             1           Yes                 Yes                       1
# 1171             0           Yes                  No                       0
# 757              1  I don't know                  No                       0
#
# ...

# %%
OneHotEnc = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
X_train_onehot = OneHotEnc.fit_transform(X_train[column_list_OneHotEnc])

# %%
col_name = OneHotEnc.get_feature_names_out(column_list_OneHotEnc)

# %%
df_one = pd.DataFrame(X_train_onehot, columns=col_name, index=X_train.index)
X_train = pd.concat([df_one, X_train.drop(column_list_OneHotEnc, axis=1)], axis=1)
X_train
# Out:
#       benefits_I don't know  benefits_No  benefits_Yes  \
# 237                     0.0          0.0           1.0
# 467                     0.0          0.0           1.0
# 216                     0.0          0.0           1.0
# 146                     0.0          0.0           1.0
# 407                     1.0          0.0           0.0
# ...                     ...          ...           ...
# 1094                    0.0          0.0           1.0
# 1146                    0.0          1.0           0.0
# 1181                    0.0          1.0           0.0
# 898                     0.0          0.0           1.0
# 1177                    0.0          1.0           0.0
#
#       workplace_resources_I don't know  workplace_resources_No  \
# 237                                0.0                     1.0
# 467                                0.0                     0.0
# 216                                0.0                     1.0
# ...

# %%
X_test_onehot = OneHotEnc.transform(X_test[column_list_OneHotEnc])
df_test_onehot = pd.DataFrame(X_test_onehot, columns=col_name, index=X_test.index)
X_test = pd.concat([df_test_onehot, X_test.drop(column_list_OneHotEnc, axis=1)], axis=1)
X_test
# Out:
#       benefits_I don't know  benefits_No  benefits_Yes  \
# 328                     0.0          0.0           1.0
# 1208                    0.0          0.0           1.0
# 948                     0.0          0.0           1.0
# 89                      0.0          0.0           1.0
# 979                     0.0          0.0           1.0
# ...                     ...          ...           ...
# 341                     0.0          1.0           0.0
# 53                      0.0          1.0           0.0
# 1232                    0.0          0.0           1.0
# 1171                    0.0          0.0           1.0
# 757                     1.0          0.0           0.0
#
#       workplace_resources_I don't know  workplace_resources_No  \
# 328                                1.0                     0.0
# 1208                               0.0                     1.0
# 948                                0.0                     0.0
# ...

# %%
data['gender'].value_counts()
# Out:
# gender
# Male      813
# Female    375
# Other      54
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

num_columns = ['age', 'mh_share']
scaler = StandardScaler()
X_train[num_columns] = scaler.fit_transform(X_train[num_columns])
X_test[num_columns] = scaler.transform(X_test[num_columns])

# %%
X_train[num_columns].describe()
# Out:
#                 age      mh_share
# count  1.069000e+03  1.069000e+03
# mean  -1.462296e-16 -6.480628e-17
# std    1.000468e+00  1.000468e+00
# min   -1.964293e+00 -2.473907e+00
# 25%   -7.445260e-01 -5.940331e-01
# 50%   -1.346422e-01  1.579164e-01
# 75%    5.972182e-01  9.098660e-01
# max    3.768614e+00  1.285841e+00

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(C=1, penalty='l2', solver='liblinear')
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1, solver='liblinear')

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(metric='manhattan', n_neighbors=19, weights='uniform')
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=19)

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(criterion='entropy', random_state=42, max_depth=5, max_features='log2',
                              min_samples_split=5, min_samples_leaf=2)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, max_features='log2',
#                        min_samples_leaf=2, min_samples_split=5,
#                        random_state=42)

# %%
from sklearn.tree import plot_tree

plot_tree(tree)
# Out:
# [Text(0.5982142857142857, 0.9166666666666666, 'x[0] <= 0.5\nentropy = 0.942\nsamples = 1069\nvalue = [384, 685]'),
#  Text(0.34523809523809523, 0.75, 'x[40] <= 0.346\nentropy = 0.902\nsamples = 792\nvalue = [252, 540]'),
#  Text(0.47172619047619047, 0.8333333333333333, 'True  '),
#  Text(0.19047619047619047, 0.5833333333333334, 'x[37] <= 0.5\nentropy = 0.958\nsamples = 423\nvalue = [161, 262]'),
#  Text(0.09523809523809523, 0.4166666666666667, 'x[35] <= 0.5\nentropy = 0.988\nsamples = 296\nvalue = [129, 167]'),
#  Text(0.047619047619047616, 0.25, 'x[31] <= 0.5\nentropy = 0.997\nsamples = 81\nvalue = [43, 38]'),
#  Text(0.023809523809523808, 0.08333333333333333, 'entropy = 0.999\nsamples = 77\nvalue = [40.0, 37.0]'),
#  Text(0.07142857142857142, 0.08333333333333333, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.14285714285714285, 0.25, 'x[5] <= 0.5\nentropy = 0.971\nsamples = 215\nvalue = [86, 129]'),
# ...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

log_accuracy_test = accuracy_score(y_test, model.predict(X_test))
log_precision_test = precision_score(y_test, model.predict(X_test))
log_recall_test = recall_score(y_test, model.predict(X_test))
log_f1_test = f1_score(y_test, model.predict(X_test))
log_cm_test = confusion_matrix(y_test, model.predict(X_test))

knn_accuracy_test = accuracy_score(y_test, knn.predict(X_test))
knn_precision_test = precision_score(y_test, knn.predict(X_test))
knn_recall_test = recall_score(y_test, knn.predict(X_test))
knn_f1_test = f1_score(y_test, knn.predict(X_test))
knn_cm_test = confusion_matrix(y_test, knn.predict(X_test))

tree_accuracy_test = accuracy_score(y_test, tree.predict(X_test))
tree_precision_test = precision_score(y_test, tree.predict(X_test))
tree_recall_test = recall_score(y_test, tree.predict(X_test))
tree_f1_test = f1_score(y_test, tree.predict(X_test))
tree_cm_test = confusion_matrix(y_test, tree.predict(X_test))

tbl_test = pd.DataFrame({
    'Accuracy': [log_accuracy_test, knn_accuracy_test, tree_accuracy_test],
    'Precision': [log_precision_test, knn_precision_test, tree_precision_test],
    'Recall': [log_recall_test, knn_recall_test, tree_recall_test],
    'F1': [log_f1_test, knn_f1_test, tree_f1_test]
}, index=['LogReg', 'KNN', 'Tree'])

tbl_test
# Out:
#         Accuracy  Precision    Recall        F1
# LogReg  0.689076   0.739130  0.839506  0.786127
# KNN     0.697479   0.741935  0.851852  0.793103
# Tree    0.714286   0.742268  0.888889  0.808989

# %%
knn_cm_test
# Out:
# array([[14, 24],
#        [12, 69]], dtype=int64)

# %%
log_cm_test
# Out:
# array([[14, 24],
#        [13, 68]], dtype=int64)

# %%
tree_cm_test
# Out:
# array([[13, 25],
#        [ 9, 72]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier

forest_model = RandomForestClassifier(max_depth= 5, max_features = 0.3, min_samples_leaf = 10, min_samples_split = 5, n_estimators = 100)
forest_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=0.3, min_samples_leaf=10,
#                        min_samples_split=5)

# %%
forest_accuracy_test = accuracy_score(y_test, forest_model.predict(X_test))
forest_precision_test = precision_score(y_test, forest_model.predict(X_test))
forest_recall_test = recall_score(y_test, forest_model.predict(X_test))
forest_f1_test = f1_score(y_test, forest_model.predict(X_test))
forest_cm_test = confusion_matrix(y_test, forest_model.predict(X_test))

tbl_test1 = pd.DataFrame({
    'Accuracy': [log_accuracy_test, knn_accuracy_test, tree_accuracy_test, forest_accuracy_test],
    'Precision': [log_precision_test, knn_precision_test, tree_precision_test, forest_precision_test],
    'Recall': [log_recall_test, knn_recall_test, tree_recall_test, forest_recall_test],
    'F1': [log_f1_test, knn_f1_test, tree_f1_test, forest_f1_test]
}, index=['LogReg', 'KNN', 'Tree', 'RandomForest'])

tbl_test1
# Out:
#               Accuracy  Precision    Recall        F1
# LogReg        0.689076   0.739130  0.839506  0.786127
# KNN           0.697479   0.741935  0.851852  0.793103
# Tree          0.714286   0.742268  0.888889  0.808989
# RandomForest  0.714286   0.728155  0.925926  0.815217

# %%
forest_cm_test
# Out:
# array([[10, 28],
#        [ 6, 75]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

log_accuracy_train = accuracy_score(y_train, model.predict(X_train))
log_precision_train = precision_score(y_train, model.predict(X_train))
log_recall_train = recall_score(y_train, model.predict(X_train))
log_f1_train = f1_score(y_train, model.predict(X_train))
log_cm_train = confusion_matrix(y_train, model.predict(X_train))

knn_accuracy_train = accuracy_score(y_train, knn.predict(X_train))
knn_precision_train = precision_score(y_train, knn.predict(X_train))
knn_recall_train = recall_score(y_train, knn.predict(X_train))
knn_f1_train = f1_score(y_train, knn.predict(X_train))
knn_cm_train = confusion_matrix(y_train, knn.predict(X_train))

tree_accuracy_train = accuracy_score(y_train, tree.predict(X_train))
tree_precision_train = precision_score(y_train, tree.predict(X_train))
tree_recall_train = recall_score(y_train, tree.predict(X_train))
tree_f1_train = f1_score(y_train, tree.predict(X_train))
tree_cm_train = confusion_matrix(y_train, tree.predict(X_train))

forest_accuracy_train = accuracy_score(y_train, forest_model.predict(X_train))
forest_precision_train = precision_score(y_train, forest_model.predict(X_train))
forest_recall_train = recall_score(y_train, forest_model.predict(X_train))
forest_f1_train = f1_score(y_train, forest_model.predict(X_train))
forest_cm_train = confusion_matrix(y_train, forest_model.predict(X_train))

tbl_train = pd.DataFrame({
    'Accuracy': [log_accuracy_train, knn_accuracy_train, tree_accuracy_train, forest_accuracy_train],
    'Precision': [log_precision_train, knn_precision_train, tree_precision_train, forest_precision_train],
    'Recall': [log_recall_train, knn_recall_train, tree_recall_train, forest_recall_train],
    'F1': [log_f1_train, knn_f1_train, tree_f1_train, forest_f1_train]
}, index=['LogReg', 'KNN', 'Tree', 'RandomForest'])

tbl_train
# Out:
#               Accuracy  Precision    Recall        F1
# LogReg        0.711880   0.745124  0.836496  0.788171
# KNN           0.709074   0.734925  0.854015  0.790007
# Tree          0.679139   0.710591  0.842336  0.770875
# RandomForest  0.720299   0.719818  0.922628  0.808701

# %%
tbl_test
# Out:
#         Accuracy  Precision    Recall        F1
# LogReg  0.689076   0.739130  0.839506  0.786127
# KNN     0.697479   0.741935  0.851852  0.793103
# Tree    0.714286   0.742268  0.888889  0.808989

# %%
from sklearn.metrics import roc_auc_score, roc_curve
from matplotlib import pyplot as plt

tree_predict_proba = tree.predict_proba(X_test)[:, 1]
tree_roc_auc = roc_auc_score(y_test, tree_predict_proba)
tree_fpr, tree_tpr, tree_thresholds = roc_curve(y_test, tree_predict_proba)

log_pred_proba = model.predict_proba(X_test)[:, 1]
log_roc_auc = roc_auc_score(y_test, log_pred_proba)
log_fpr, log_tpr, log_thresholds = roc_curve(y_test, log_pred_proba)

knn_pred_proba = knn.predict_proba(X_test)[:, 1]
knn_roc_auc = roc_auc_score(y_test, knn_pred_proba)
knn_fpr, knn_tpr, knn_thresholds = roc_curve(y_test, knn_pred_proba)

plt.figure(figsize=(8, 7))
plt.plot(tree_fpr, tree_tpr, color='blue', label=f'Tree_Auc {tree_roc_auc}')
plt.plot(log_fpr, log_tpr, color='purple', label=f'LogReg_Auc {log_roc_auc}')
plt.plot(knn_fpr, knn_tpr, color='red', label=f'KNN_Auc{knn_roc_auc}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Roc-Auc for 3 models')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

knn_params = {
    'n_neighbors': list(range(1, 20)),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

knn_search = GridSearchCV(KNeighborsClassifier(), knn_params, cv=5, scoring='roc_auc', n_jobs=-1)
knn_search.fit(X_train, y_train)

print("Лучшие параметры для KNN:", knn_search.best_params_)
print("Лучший ROC AUC:", knn_search.best_score_)
# Out:
# Лучшие параметры для KNN: {'metric': 'manhattan', 'n_neighbors': 19, 'weights': 'uniform'}
# Лучший ROC AUC: 0.7033775962800166

# %%
log_params = [
    {'C': list(range(1, 20)), 'penalty': ['l2'], 'solver': ['lbfgs']},
    {'C': list(range(1, 20)), 'penalty': ['l1', 'l2'], 'solver': ['liblinear']}
]

log_search = GridSearchCV(LogisticRegression(), log_params, cv=5, scoring='roc_auc', n_jobs=-1)
log_search.fit(X_train, y_train)

print("Best parametrs for LogReg:", log_search.best_params_)
print("Best score for LogReg:", log_search.best_score_)
# Out:
# Best parametrs for LogReg: {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# Best score for LogReg: 0.7309384526345724

# %%
tree_params = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 5, 10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5],
    'max_features': ['auto', 'sqrt', 'log2'],
    'splitter': ['best', 'random'],
    'max_leaf_nodes': [10, 20, 50, None],
    'min_impurity_decrease': [0, 0.01, 0.1]
}

tree_search = GridSearchCV(DecisionTreeClassifier(), tree_params, cv=5, scoring='roc_auc', n_jobs=-1)
tree_search.fit(X_train, y_train)

print("Best parametrs for DecisionTree:", tree_search.best_params_)
print("Best score for DecisionTree:", tree_search.best_score_)
# Out:
# C:\Users\akbar\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 10800 fits failed out of a total of 32400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4958 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\akbar\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\akbar\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
# ...

# %%
from sklearn.ensemble import BaggingClassifier

logreg_bg = LogisticRegression(C=1, penalty='l2', solver='liblinear')
bagging = BaggingClassifier(logreg_bg, random_state=42, n_jobs=-1, bootstrap=True, max_features=0.8, max_samples=0.8,
                            n_estimators=100)

bagging.fit(X_train, y_train)
bg_accuracy = accuracy_score(y_train, bagging.predict(X_train))
bg_precision = precision_score(y_train, bagging.predict(X_train))
bg_recall = recall_score(y_train, bagging.predict(X_train))
bg_f1 = f1_score(y_train, bagging.predict(X_train))
bg_cm = confusion_matrix(y_train, bagging.predict(X_train))

tbl_bg_train = pd.DataFrame({
    'Accuracy': [bg_accuracy],
    'Precision': [bg_precision],
    'Recall': [bg_recall],
    'F1': [bg_f1]
}, index=['Bagging'])

tbl_bg_train
# Out:
#          Accuracy  Precision    Recall       F1
# Bagging  0.707203   0.727384  0.868613  0.79175

# %%
bg_accuracy_test = accuracy_score(y_test, bagging.predict(X_test))
bg_precision_test = precision_score(y_test, bagging.predict(X_test))
bg_recall_test = recall_score(y_test, bagging.predict(X_test))
bg_f1_test = f1_score(y_test, bagging.predict(X_test))
bg_cm_test = confusion_matrix(y_test, bagging.predict(X_test))

tbl_bg_test = pd.DataFrame({
    'Accuracy': [bg_accuracy_test],
    'Precision': [bg_precision_test],
    'Recall': [bg_recall_test],
    'F1': [bg_f1_test]
}, index=['Bagging'])

tbl_bg_test
# Out:
#          Accuracy  Precision    Recall        F1
# Bagging  0.722689       0.75  0.888889  0.813559

# %%
bg_cm_test
# Out:
# array([[14, 24],
#        [ 9, 72]], dtype=int64)

# %%
log_cm_train
# Out:
# array([[188, 196],
#        [112, 573]], dtype=int64)

# %%
bg_pred_proba = bagging.predict_proba(X_test)[:, 1]
bg_roc_auc = roc_auc_score(y_test, bg_pred_proba)
bg_fpr, bg_tpr, bg_thresholds = roc_curve(y_test, bg_pred_proba)

forest_pred_proba = forest_model.predict_proba(X_test)[:, 1]
forest_roc_auc = roc_auc_score(y_test, forest_pred_proba)
forest_fpr, forest_tpr, forest_thresholds = roc_curve(y_test, forest_pred_proba)

plt.figure(figsize=(8, 7))
plt.plot(forest_fpr, forest_tpr, color = 'green', label=f'Random Forest Auc {forest_roc_auc}')
plt.plot(bg_fpr, bg_tpr, color='yellow', label=f'Bagging Auc {bg_roc_auc}')
plt.plot(tree_fpr, tree_tpr, color='blue', label=f'Tree_Auc {tree_roc_auc}')
plt.plot(log_fpr, log_tpr, color='purple', label=f'LogReg_Auc {log_roc_auc}')
plt.plot(knn_fpr, knn_tpr, color='red', label=f'KNN_Auc{knn_roc_auc}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Roc-Auc for 3 models')
plt.legend(loc='lower right')
plt.show()

# %%
pd.concat([tbl_test1, tbl_bg_test])
# Out:
#               Accuracy  Precision    Recall        F1
# LogReg        0.689076   0.739130  0.839506  0.786127
# KNN           0.697479   0.741935  0.851852  0.793103
# Tree          0.714286   0.742268  0.888889  0.808989
# RandomForest  0.714286   0.728155  0.925926  0.815217
# Bagging       0.722689   0.750000  0.888889  0.813559

# %%
pd.concat([tbl_train, tbl_bg_train])
# Out:
#               Accuracy  Precision    Recall        F1
# LogReg        0.711880   0.745124  0.836496  0.788171
# KNN           0.709074   0.734925  0.854015  0.790007
# Tree          0.679139   0.710591  0.842336  0.770875
# RandomForest  0.720299   0.719818  0.922628  0.808701
# Bagging       0.707203   0.727384  0.868613  0.791750

# %%
forest_params = {
    'n_estimators': [50, 100, 200],
    'max_depth': [ 3, 5, 7, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': [0.3, 0.5, 1.0]

}

forest_search = GridSearchCV(RandomForestClassifier(), forest_params, cv=5, scoring='roc_auc', n_jobs=-1)
forest_search.fit(X_train, y_train)

print("Best parametrs for Forest:", forest_search.best_params_)
print("Best score for Forest:", forest_search.best_score_)
# Out:
# Best parametrs for Forest: {'max_depth': 5, 'max_features': 0.3, 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 200}
# Best score for Forest: 0.724651999940129
